# %% [markdown]
# ## Python OS Module
# The os module in Python provides a way of interacting with the operating system. It provides a way to access and manipulate files and directories, start and stop processes, get information about the system, and more.

# %% [markdown]
# # Working with Files and Directories

# %% [markdown]
# Let's explore the os module and its various functions and methods that support working with files and directories.

# %% [markdown]
# os.getcwd(): Get the current working directory
# os.mkdir('path'): Create a new directory
# os.chdir('path'): Change the current working directory
# os.listdir('path'): List the contents of a directory
# os.rename('old_name', 'new_name): Rename a file or a directory
# os.remove('file_to_delete'): Remove a file
# os.rmdir('directory_to_delete'): Remove a directory
# os.path.dirname('path'): Returns the name of the directory containing pathname path
# os.path.exists('path'): Checks if the path already exists, if so returns True

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/ganeshpokharel/Desktop/datascience/Day10/module_and_packages'

# %%
file_path = "test/file.txt"
if os.path.exists(file_path):
    pass
else:
    print("File doesn't exist")
# Out:
# File doesn't exist

# %%
os.makedirs("test/", exist_ok=True)

# %%
os.path.join("test/","file.txt")
# Out:
# 'test/file.txt'

# %%
os.listdir(".")
# Out:
# ['test', 'OSmodule.ipynb', '.ipynb_checkpoints']

# %% [markdown]
# # Working with Environment Variables
# The os module provides functions for working with environment variables. Here are some of the most commonly used functions:

# %%
os.getenv('var_name'): Get the value of an Environment Variable
os.environ['var_name'] = 'var_value': Set the Value of an Environment Variable

# %%
os.environ
# Out:
# environ{'TMPDIR': '/var/folders/bt/pcxs82x914b3zh57lplprzg80000gn/T/',
#         '__CFBundleIdentifier': 'com.apple.Terminal',
#         'XPC_FLAGS': '0x0',
#         'TERM': 'xterm-color',
#         'SSH_AUTH_SOCK': '/private/tmp/com.apple.launchd.bLLPWE6s1z/Listeners',
#         'XPC_SERVICE_NAME': '0',
#         'TERM_PROGRAM': 'Apple_Terminal',
#         'COLORTERM': 'truecolor',
#         'OSLogRateLimit': '64',
#         'TERM_PROGRAM_VERSION': '465',
#         'TERM_SESSION_ID': '53520B23-7FA4-4307-8451-C0580C3087BB',
#         'SHELL': '/bin/zsh',
#         'HOME': '/Users/ganeshpokharel',
#         'LOGNAME': 'ganeshpokharel',
#         'USER': 'ganeshpokharel',
#         'PATH': '/Library/Frameworks/Python.framework/Versions/3.13/bin:/usr/local/bin:/System/Cryptexes/App/usr/bin:/usr/bin:/bin:/usr/sbin:/sbin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/local/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/appleinternal/bin:/opt/pmk/env/global/bin:/opt/homebrew/bin',
#         'SHLVL': '1',
#         'PWD': '/Users/ganeshpokharel/desktop/datascience/day10',
#         'OLDPWD': '/Users/ganeshpokharel/desktop/datascience',
#         'LANG': 'C.UTF-8',
#         'LC_CTYPE': 'UTF-8',
#         '_': '/Library/Frameworks/Python.framework/Versions/3.13/bin/jupyter',
#         '__CF_USER_TEXT_ENCODING': '0x1F5:0x0:0x0',
#         'JPY_SESSION_NAME': '/Users/ganeshpokharel/Desktop/datascience/Day10/module_and_packages/Untitled.ipynb',
#         'JPY_PARENT_PID': '54852',
#         'PYDEVD_USE_FRAME_EVAL': 'NO',
#         'CLICOLOR': '1',
#         'FORCE_COLOR': '1',
#         'CLICOLOR_FORCE': '1',
#         'PAGER': 'cat',
#         'GIT_PAGER': 'cat',
#         'MPLBACKEND': 'module://matplotlib_inline.backend_inline'}

# %%
os.environ["MyPass"] = "reahbspgbinaswoOGBJ;asJBAW;SJGVN"

# %%
os.getenv("MyPass")
# Out:
# 'reahbspgbinaswoOGBJ;asJBAW;SJGVN'

# %%
os.getenv("OneDrive")
