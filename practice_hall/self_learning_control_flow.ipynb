# %%
#if statement
x = int(input("enter an integer number: "))

if x < 0:
    print("negative number")
elif x == 0:
    print("zero")
elif x == 1:
    print("yes")
elif x >= 90:
    print("hello jee namaste")
else:
    print("good bye")
# Out:
# enter an integer number:  23
# good bye

# %%
word = ["HARI ","SHYAM","GANESH","BILLION"]
for i in words:
    print(i, len(i))
# Out:
# HARI  5
# SHYAM 5
# GANESH 6
# BILLION 7
