# %% [markdown]
# # 1. Notebook Structure
# 1. Introduction
# 2. Import Libraries
# 3. Load Dataset
# 4. Basic Data Understanding
# 5. Data Cleaning
# 6. Univariate Analysis
# 7. Bivariate Analysis
# 8. Multivariate Analysis
# 9. Key Insights
# 10. Conclusion

# %% [markdown]
# # 2. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # 3. Load Dataset

# %%
df = pd.read_csv("iris.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 6)

# %% [markdown]
# * This data set contains 150 observations and 6 features to iris flowers.

# %% [markdown]
# # 4. Basic Understanding

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# * All numerical features are float
#
# * Target variable: Species
#
# * No missing values observed

# %% [markdown]
# # 5. Data Cleaning

# %%
df.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# * No missing or duplicate records were found. The dataset is clean and ready for analysis.

# %% [markdown]
# # 6. Univariate Analysis

# %%
sns.histplot(np.log1p(df[col]),
             bins=30,
             kde=True)
plt.title(f"Log Distribution of {col}")
plt.show()

# %% [markdown]
# * Sepal features show moderate spread
#
# * Petal features are more concentrated

# %% [markdown]
# # 7. Bivariate Analysis

# %%
plt.figure(figsize=(6,4))
sns.scatterplot(
    data=df,
    x="PetalLengthCm",
    y="PetalWidthCm",
    hue="Species"
)
plt.title("Petal Length vs Petal Width by Species")
plt.show()

# %% [markdown]
# * Setosa species is clearly separable using petal measurements, while versicolor and virginica show some overlap.

# %% [markdown]
#  # 8. Multivariate Analysis (Correlation)

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df.drop("Species", axis=1).corr(), 
            annot=True)
plt.title("Feature Correlation Matrix")
plt.show()

# %% [markdown]
# * Petal length and width are highly correlated
#
# * Sepal features have weaker relationships

# %% [markdown]
# # 9. Key Insights

# %% [markdown]
# * Petal measurements are the strongest indicators of iris species
#
# * Setosa is linearly separable from other species
#
# * Sepal features contribute less to classification
#
# * Simple models can achieve high accuracy using petal features alone

# %% [markdown]
# # 10. Final Conclusion

# %% [markdown]
# This exploratory analysis demonstrates that iris species can be effectively distinguished using petal dimensions. The dataset is clean, well-balanced, and suitable for both classification and educational purposes.
