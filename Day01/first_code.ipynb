# %%
print("Hello world")
# Out:
# Hello world

# %%
print('Hello Ganesh')
# Out:
# Hello Ganesh

# %%
Print('''Ganesh ji how are you?''')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 Print('''Ganesh ji how are you?''')
#
# NameError: name 'Print' is not defined
